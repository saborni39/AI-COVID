# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#pip install --upgrade numpy

# %%
data = pd.read_excel('final_cleaned_dataset.xlsx', header=0)

# %%
data.head(2)
# Out:
#    Unnamed: 0      District  \
# 0           0     Ahrweiler
# 1           1  Altenkirchen
#
#    Laboratory confirmed, since the beginning of the pandemic TOTAL  \
# 0                                               4577
# 1                                               4956
#
#    Laboratory confirmed, since the beginning of the pandemic Difference from  \
# 0                                                  4
# 1                                                  0
#
#    Laboratory confirmed, since the beginning of the pandemic Hospitalized  \
# 0                                                199
# 1                                                411
#
#    Laboratory confirmed, since the beginning of the pandemic Deceased  \
# 0                                               52.0
# 1                                              101.0
#
#    Laboratory confirmed, since the beginning of the pandemic RecoveredA  \
# 0                                               4423
# ...

# %% [markdown]
# ##  1. Relationship: All Districts & Laboratory confirmed Hospitalized

# %% [markdown]
# ##  1.a. SCATTER PLOT

# %%
plt.figure(figsize=(15, 4))  

x = data['District'].astype(str)
y = data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].astype(str)

plt.scatter(x,y,color='brown') 

plt.xlabel('X : District')
plt.xticks(rotation = 'vertical') 

plt.ylabel('Y : Hospitalized', fontsize=12, color='black')
plt.yticks([-20, -10, 0, 10, 20], fontsize=10)

plt.title('Relationship: All Districts and Laboratory confirmed Hospitalized')
plt.show()

# %% [markdown]
# #  1.b. BAR PLOT

# %%
# Grouping by district and calculating the sum of infections
district_hospitalized = data.groupby("District")["Laboratory confirmed, since the beginning of the pandemic Hospitalized"].sum().reset_index()

# the aggregated data
#print(district_hospitalized)

plt.figure(figsize=(12, 6))
plt.bar(district_hospitalized["District"], district_hospitalized["Laboratory confirmed, since the beginning of the pandemic Hospitalized"])

plt.xlabel("District")
plt.ylabel("Sum of Hospitalized")
plt.xticks(rotation = 'vertical') 

plt.title("Sum of Hospitalized by District")
plt.show()

# %% [markdown]
# #  1.c. LINE GRAPH

# %%
plt.figure(figsize=(10, 6))
plt.plot(district_hospitalized["District"], district_hospitalized["Laboratory confirmed, since the beginning of the pandemic Hospitalized"], color='green')

plt.xlabel('X: District')
plt.ylabel('Y: Hospitalized')
plt.xticks(rotation = 'vertical',color='black')

plt.title('Relationship: All Districts and Laboratory confirmed Hospitalized')
plt.show()

# %% [markdown]
# #  2. Relationship: All Districts & Laboratory confirmed Current Cases

# %% [markdown]
# ##  2.a. SCATTER PLOT

# %%
plt.figure(figsize=(15, 4))  

x = data['District'].astype(str)
y = data['Laboratory confirmed, since the beginning of the pandemic Current CasesB'].astype(str)

plt.scatter(x,y)  

plt.xlabel('X : Location')
plt.ylabel('Y : Hospitalized', fontsize=12, color='black')
plt.yticks([-20, -10, 0, 10, 20], fontsize=10)
plt.xticks(rotation = 'vertical') 

plt.title('Relationship: All Districts and Laboratory confirmed Current CasesB')
plt.show()

# %%
# Save the plot as a PNG image
plt.savefig('Districts VS Current Cases.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #  2.b. BAR PLOT

# %%
# Grouping by district and calculating the sum of infections
district_currentcases = data.groupby("District")["Laboratory confirmed, since the beginning of the pandemic Current CasesB"].sum().reset_index()

# the aggregated data
#print(district_currentcases)

plt.figure(figsize=(12, 6))
plt.bar(district_currentcases["District"], district_currentcases["Laboratory confirmed, since the beginning of the pandemic Current CasesB"],color='purple')

plt.xlabel("District")
plt.ylabel("Sum of Laboratory confirmed Current Cases")
plt.xticks(rotation = 'vertical') 

plt.title("Sum of Laboratory confirmed Current Cases by District")
plt.show()

# %% [markdown]
# #  2.c. LINE GRAPH

# %%
plt.figure(figsize=(10, 6))
plt.plot(district_currentcases["District"], district_currentcases["Laboratory confirmed, since the beginning of the pandemic Current CasesB"],color='brown')

plt.xlabel('X: District')
plt.ylabel('Y: Current Cases')
plt.xticks(rotation = 'vertical')

plt.title('Relationship: All Districts and Laboratory confirmed Current Cases')
plt.show()

# %% [markdown]
# #  3. Relationship: All Districts & Laboratory confirmed Recovered

# %% [markdown]
# #  3.a. SCATTER PLOT

# %%
plt.figure(figsize=(13, 6))  

x = data['District'].astype(str)
y = data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'].astype(str)

plt.scatter(x,y,color='green') 

plt.xlabel('X : District')
plt.xticks(rotation = 'vertical') 

plt.ylabel('Y : Recovered', fontsize=12, color='black')
plt.yticks([-20, -10, 0, 10, 20], fontsize=10)

plt.title('Relationship: All Districts and Laboratory confirmed Recovered')
plt.show()

# %% [markdown]
# #  3.b. BAR PLOT

# %%
# Grouping by district and calculating the sum of infections
district_recovered = data.groupby("District")["Laboratory confirmed, since the beginning of the pandemic RecoveredA"].sum().reset_index()

# the aggregated data
#print(district_recovered)

plt.figure(figsize=(12, 6))
plt.bar(district_recovered["District"], district_recovered["Laboratory confirmed, since the beginning of the pandemic RecoveredA"],color='maroon')

plt.xlabel("District")
plt.ylabel("Sum of Laboratory confirmed Recovered")
plt.xticks(rotation = 'vertical') 

plt.title("Sum of Laboratory confirmed Recovered Cases by District")
plt.show()

# %% [markdown]
# #  3.c. LINE GRAPH

# %%
plt.figure(figsize=(10, 6))
plt.plot(district_recovered["District"], district_recovered["Laboratory confirmed, since the beginning of the pandemic RecoveredA"],color='purple')

plt.xlabel('X: District')
plt.ylabel('Y: Recovered Cases')
plt.xticks(rotation = 'vertical')

plt.title('Relationship: All Districts and Laboratory confirmed Recovered Cases')
plt.show()

# %% [markdown]
# #  4. Relationship: All Districts & Laboratory confirmed Deceased

# %% [markdown]
# #  4.a. SCATTER PLOT

# %%
plt.figure(figsize=(15, 6))  

x = data['District'].astype(str)
y = data['Laboratory confirmed, since the beginning of the pandemic Deceased'].astype(str)

plt.scatter(x,y,color='gray') 

plt.xlabel('X : District')
plt.xticks(rotation = 'vertical') 

plt.ylabel('Y : Deceased', fontsize=12, color='black')
plt.yticks([-20, -10, 0, 10, 20], fontsize=10)

plt.title('Relationship: All Districts and Laboratory confirmed Deceased')
plt.show()

# %% [markdown]
# #  4.b. BAR PLOT

# %%
# Grouping by district and calculating the sum of infections
district_deceased = data.groupby("District")["Laboratory confirmed, since the beginning of the pandemic Deceased"].sum().reset_index()

# the aggregated data
#print(district_deceased)

plt.figure(figsize=(12, 6))
plt.bar(district_deceased["District"], district_deceased["Laboratory confirmed, since the beginning of the pandemic Deceased"],color='green')

plt.xlabel("District")
plt.ylabel("Sum of Laboratory confirmed Deceased")
plt.xticks(rotation = 'vertical') 

plt.title("Sum of Laboratory confirmed Deceased Cases by District")
plt.show()

# %% [markdown]
# #  4.c. LINE GRAPH

# %%
plt.figure(figsize=(10, 6))
plt.plot(district_deceased["District"], district_deceased["Laboratory confirmed, since the beginning of the pandemic Deceased"],color='orange')

plt.xlabel('X: District')
plt.ylabel('Y: Deceased Cases')
plt.xticks(rotation = 'vertical')

plt.title('Relationship: All Districts and Laboratory confirmed Deceased Cases')
plt.show()

# %% [markdown]
# # 5. Difference plotting between Hospitalized and Recovered Cases

# %% [markdown]
# # 5.a. PLOT Hospitalized vs Recovered COVID Cases

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'], label='Hospitalized',color='red')
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], label='Recovered', color='yellow')
plt.xlabel('Time phase')
plt.ylabel('Number of Cases')
plt.legend()
plt.title('Hospitalized vs Recovered COVID Cases')
plt.show()

# %% [markdown]
# # 5.b. Scatter PLOT

# %%
data["difference1"] = data["Laboratory confirmed, since the beginning of the pandemic RecoveredA"] - data["Laboratory confirmed, since the beginning of the pandemic Hospitalized"] 
data["difference1"] = pd.to_numeric(data["difference1"], errors="coerce")

plt.figure(figsize=(10, 6))
district_difference1 = data.groupby("District")["difference1"].sum().reset_index()
plt.scatter(district_difference1["District"], district_difference1["difference1"],color='maroon')

plt.xlabel("District")
plt.ylabel("Difference")
plt.title("Differences between Hospitalized and Recovered Cases")
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# # 5.c. PIE CHART

# %%
plt.figure(figsize=(6, 6))
labels = ["Hospitalized", "Recovered"]
sizes = [data["Laboratory confirmed, since the beginning of the pandemic Hospitalized"].iloc[-1], data["Laboratory confirmed, since the beginning of the pandemic RecoveredA"].iloc[-1]]
plt.pie(sizes, labels=labels, autopct="%1.1f%%", colors=["cyan", "pink"])
plt.title("Distribution of Hospitalized and Recovered Cases")
plt.show()

# %% [markdown]
# # 6.Recovered vs Deceased COVID Cases

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], label='Recovered')
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic Deceased'], label='Deceased')
plt.xlabel('Time phase')
plt.ylabel('Number of Cases')
plt.legend()
plt.title('Recovered vs Deceased COVID Cases')
plt.show()

# %% [markdown]
# # 7. Difference plotting between Hospitalized and Deceased Cases

# %% [markdown]
# # 7.a. BAR PLOT

# %%
data["difference"] = data["Laboratory confirmed, since the beginning of the pandemic Hospitalized"] - data["Laboratory confirmed, since the beginning of the pandemic Deceased"]
data["difference"] = pd.to_numeric(data["difference"], errors="coerce")

plt.figure(figsize=(10, 6))
district_difference = data.groupby("District")["difference"].sum().reset_index()
plt.bar(district_difference["District"], district_difference["difference"],color='purple')

plt.xlabel("District")
plt.ylabel("Difference")
plt.title("Differences between Hospitalized and Deceased Cases")
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# # 7.b. PIE CHART

# %%
plt.figure(figsize=(6, 6))
labels = ["Hospitalized", "Deceased"]
sizes = [data["Laboratory confirmed, since the beginning of the pandemic Hospitalized"].iloc[-1], data["Laboratory confirmed, since the beginning of the pandemic Deceased"].iloc[-1]]
plt.pie(sizes, labels=labels, autopct="%1.1f%%", colors=["lightgreen", "lightcoral"])
plt.title("Distribution of Hospitalized and Deceased Cases")
plt.show()

# %% [markdown]
# # 7.c. PLOT

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'], label='Hospitalized')
plt.plot(data['Laboratory confirmed, since the beginning of the pandemic Deceased'], label='Deceased',color='orange')
plt.xlabel('Time phase')
plt.ylabel('Number of Cases')
plt.legend()
plt.title('Hospitalized vs Deceased COVID Cases')
plt.show()

# %% [markdown]
# # 8. District wise (single) Hospitalized cases

# %%
plt.figure(figsize=(10, 4)) 
v1 = 'Ahrweiler'
xx = data[data['District'] == v1]
final_v = xx['Laboratory confirmed, since the beginning of the pandemic Hospitalized']

plt.plot(final_v)  # Line plot

plt.xlabel('X : District')
plt.ylabel('Y : Hospitalized')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Hospitalized case')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 9. District wise (single) Deceased cases

# %%
plt.figure(figsize=(10, 4))  

v2 = 'Ahrweiler'
xx1 = data[data['District'] == v2]
final_v1 = xx1['Laboratory confirmed, since the beginning of the pandemic Deceased']

plt.plot(final_v1,color='brown')  # Line plot

plt.xlabel('X : District')
plt.ylabel('Y : Deceased')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Deceased case')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 10. District wise (single) Recovered cases

# %%
plt.figure(figsize=(10, 4))

v3 = 'Ahrweiler'
xx2 = data[data['District'] == v3]
final_v2 = xx2['Laboratory confirmed, since the beginning of the pandemic RecoveredA']

plt.plot(final_v2,color='purple')  # Line plot

plt.xlabel('X : District')
plt.ylabel('Y : Recovered')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Recovered case')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 11. District wise (single) Current cases

# %%
plt.figure(figsize=(10, 4)) 

v4 = 'Ahrweiler'
xx3 = data[data['District'] == v4]
final_v3 = xx3['Laboratory confirmed, since the beginning of the pandemic Current CasesB']

plt.plot(final_v3,color='green')  # Line plot

plt.xlabel('X : District')
plt.ylabel('Y : Current Cases')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Current Cases')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 12.Relationship: All Districts and Laboratory confirmed TOTAL Cases

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

x4 = data['District'].astype(str)
y4 = data['Laboratory confirmed, since the beginning of the pandemic TOTAL'].astype(str)

plt.scatter(x4, y4)

plt.xlabel('X : District')
plt.ylabel('Y : TOTAL cases', fontsize=12, color='black')
plt.yticks([-20, -10, 0, 10, 20], fontsize=10)
plt.title('Relationship: All Districts and Laboratory confirmed TOTAL Cases')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 13. District wise (single) Confirmed Total cases

# %%
plt.figure(figsize=(10, 4))  

v5 = 'Ahrweiler'
xx4 = data[data['District'] == v5]
final_v4 = xx4['Laboratory confirmed, since the beginning of the pandemic TOTAL']

plt.plot(final_v4)  # Line plot

plt.xlabel('X : District')
plt.ylabel('Y : TOTAL cases')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed TOTAL Cases')
plt.xticks(rotation = 'vertical')  

plt.show()

# %% [markdown]
# # 14. District wise (single) cases with pie chart

# %%
district_name = 'Ahrweiler'

district_data = data[data['District'] == district_name]

case_counts = district_data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].value_counts()

plt.figure(figsize=(10, 6))

labels = case_counts.index
values = case_counts.values

plt.pie(values, labels=None)
plt.title('Hospitalized case Distribution for {} in pie chart'.format(district_name))
plt.axis('equal')
plt.show()

# %% [markdown]
# # 15. Histogram for a single district on Recovered cases

# %%
# Searching a particular value in column
single_result = data[data['District'] == 'Ahrweiler']

#single_result.head(3)
plt.hist(single_result['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], bins=15,color='brown')
# Out:
# (array([146.,  55.,  15.,  15.,  12.,   9.,   8.,  12.,  15.,  30.,  16.,
#          24.,  36.,  18.,  53.]),
#  array([ 4423. ,  7219.6, 10016.2, 12812.8, 15609.4, 18406. , 21202.6,
#         23999.2, 26795.8, 29592.4, 32389. , 35185.6, 37982.2, 40778.8,
#         43575.4, 46372. ]),
#  <BarContainer object of 15 artists>)

# %% [markdown]
# # 16. Histogram for a single district on Deceased cases

# %%
plt.hist(single_result['Laboratory confirmed, since the beginning of the pandemic Deceased'], bins=20,color='orange')
# Out:
# (array([49., 39., 18., 10., 21.,  6., 57., 20., 36., 31., 13., 19., 24.,
#         14., 15., 13., 16., 29.,  2., 32.]),
#  array([ 52.  ,  56.35,  60.7 ,  65.05,  69.4 ,  73.75,  78.1 ,  82.45,
#          86.8 ,  91.15,  95.5 ,  99.85, 104.2 , 108.55, 112.9 , 117.25,
#         121.6 , 125.95, 130.3 , 134.65, 139.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # 17. Heatmap of the correlation matrix

# %%
# Dropping multiple columns to get only numerical value
columns_to_drop = ['District']
single_result_n = single_result.drop(columns_to_drop, axis=1)

# %%
np.bool = np.bool_

# %%
correlation_matrix = single_result_n.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',cbar_kws={'shrink': 0.7},linecolor='white',fmt='.1f', linewidths=2.0)

plt.title('Correlation Matrix')
plt.figure(figsize=(15,10))

plt.show()

# %% [markdown]
# # 18. Correlations

# %% [markdown]
# # 18.a. Pearson correlation Calculation

# %%
pearson_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='pearson').iloc[0, 1]

print('Pearson correlation:', pearson_corr)
# Out:
# Pearson correlation: 0.9735336484802769

# %% [markdown]
# # 18.b. Spearman correlation Calculation

# %%
spearman_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='spearman').iloc[0, 1]

print('Spearman correlation:', spearman_corr)
# Out:
# Spearman correlation: 0.9987149801623517

# %% [markdown]
# # 18.c. Kendalltau correlation Calculation

# %%
kendalltau_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='kendall').iloc[0, 1]

print('kendalltau correlation:', kendalltau_corr)
# Out:
# kendalltau correlation: 0.9938716306858335

# %% [markdown]
# # 19. Pearson Correlation Heatmap

# %%
from scipy.stats import pearsonr

correlation_coefficient, _ = pearsonr(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

correlation_matrix = single_result_n.corr()

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Pearson correlation: {:.2f})'.format(correlation_coefficient))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Pearson Correlation Heatmap')

plt.show()

# %% [markdown]
# # 20. Spearman Correlation Heatmap

# %%
from scipy.stats import spearmanr

correlation_coefficient, _ = spearmanr(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Spearman correlation: {:.2f})'.format(correlation_coefficient))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')
plt.show()


plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='spearman'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Spearman Correlation Heatmap')
plt.show()

# %% [markdown]
# # 21. Kendalltau Correlation Heatmap

# %%
from scipy.stats import kendalltau

correlation_coefficient1, _ = kendalltau(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Kendall correlation: {:.2f})'.format(correlation_coefficient1))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')
plt.show()


plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Kendall Correlation Heatmap')
plt.show()

# %% [markdown]
# # >=60 JAHRE & HOSPITALIZED CORRELATION

# %%
from scipy.stats import kendalltau

correlation_coefficient1, _ = kendalltau(single_result_n['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Kendall correlation: {:.2f})'.format(correlation_coefficient1))
plt.xlabel('Age wise')
plt.ylabel('Hospitalized')
plt.show()


plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Kendall Correlation Heatmap')
plt.show()

# %% [markdown]
# # 20-59 JAHRE & HOSPITALIZED CORRELATION

# %%
from scipy.stats import kendalltau

correlation_coefficient1, _ = kendalltau(single_result_n['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Kendall correlation: {:.2f})'.format(correlation_coefficient1))
plt.xlabel('Age wise')
plt.ylabel('Hospitalized')
plt.show()


plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Kendall Correlation Heatmap')
plt.show()

# %% [markdown]
# # <20 JAHRE & HOSPITALIZED CORRELATION

# %%
from scipy.stats import kendalltau

correlation_coefficient1, _ = kendalltau(single_result_n['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Kendall correlation: {:.2f})'.format(correlation_coefficient1))
plt.xlabel('Age wise')
plt.ylabel('Hospitalized')
plt.show()

plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Kendall Correlation Heatmap')
plt.show()

# %% [markdown]
# # 22. Correlation Heatmap (Recovered-Deceased)

# %%
correlation_coefficient0 = np.corrcoef(data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], data['Laboratory confirmed, since the beginning of the pandemic Deceased'])[0, 1]
plt.figure(figsize=(10, 6))
sns.scatterplot(data=single_result_n, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Deceased')
plt.title('Scatter Plot (correlation: {:.2f})'.format(correlation_coefficient0))
plt.xlabel('Recovered')
plt.ylabel('Deceased')
plt.show()


plt.figure(figsize=(10, 6))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # 23. MEAN, MEDIAN, MODE

# %% [markdown]
# # 23. a. MEAN, MEDIAN, MODE  (Recovered Cases)

# %%
mean = np.mean(data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'])
median = np.median(data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'])
mode = np.argmax(np.bincount(data["Laboratory confirmed, since the beginning of the pandemic RecoveredA"]))  

print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)


plt.figure(figsize=(8, 6))
plt.bar(["Mean", "Median", "Mode"], [mean, median, mode], color=['cyan', 'lime', 'orange'])
plt.ylabel("Value")
plt.title("Mean, Median, and Mode")
plt.show()
# Out:
# Mean: 21370.185808383234
# Median: 13306.0
# Mode: 3781

# %% [markdown]
# # 23. b. MEAN, MEDIAN, MODE  (Hospitalized Cases)

# %%
mean2 = np.mean(data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])
median2 = np.median(data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])
mode2 = np.argmax(np.bincount(data["Laboratory confirmed, since the beginning of the pandemic Hospitalized"])) 

print("Mean:", mean2)
print("Median:", median2)
print("Mode:", mode2)


plt.figure(figsize=(8, 6))
plt.bar(["Mean", "Median", "Mode"], [mean2, median2, mode2], color=['blue', 'green', 'red'])
plt.ylabel("Value")
plt.title("Mean, Median, and Mode")
plt.show()
# Out:
# Mean: 552.5140718562874
# Median: 449.0
# Mode: 379

# %% [markdown]
# # 23. c. MEAN, MEDIAN, MODE  (Current Cases)

# %%
mean3 = np.mean(data['Laboratory confirmed, since the beginning of the pandemic Current CasesB'])
median3 = np.median(data['Laboratory confirmed, since the beginning of the pandemic Current CasesB'])
mode3 = np.argmax(np.bincount(data["Laboratory confirmed, since the beginning of the pandemic Current CasesB"])) 

print("Mean:", mean3)
print("Median:", median3)
print("Mode:", mode3)

plt.figure(figsize=(8, 6))
plt.bar(["Mean", "Median", "Mode"], [mean3, median3, mode3], color=['Maroon', 'orange', 'red'])
plt.ylabel("Value")
plt.title("Mean, Median, and Mode")
plt.show()
# Out:
# Mean: 1769.3089221556886
# Median: 974.5
# Mode: 0

# %% [markdown]
# # 23. d. MEAN, MEDIAN, MODE  (Deceased Cases)

# %%
mean4 = np.mean(data['Laboratory confirmed, since the beginning of the pandemic Deceased'])
median4 = np.median(data['Laboratory confirmed, since the beginning of the pandemic Deceased'])
mode4 = np.argmax(np.bincount(data["Laboratory confirmed, since the beginning of the pandemic Deceased"])) 

print("Mean:", mean4)
print("Median:", median4)
print("Mode:", mode4)


# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(["Mean", "Median", "Mode"], [mean4, median4, mode4], color=['purple', 'pink', 'violet'])
plt.ylabel("Value")
plt.title("Mean, Median, and Mode")
plt.show()
# Out:
# Mean: 144.46275449101796
# Median: 125.0
# Mode: 95

# %% [markdown]
# # 24. Single District Visualization

# %%
selected_category = "Ahrweiler"

selected_row = data[data["District"] == selected_category]

values = selected_row[["Laboratory confirmed, since the beginning of the pandemic TOTAL", "Laboratory confirmed, since the beginning of the pandemic Hospitalized","Laboratory confirmed, since the beginning of the pandemic Deceased", "Laboratory confirmed, since the beginning of the pandemic RecoveredA","Laboratory confirmed, since the beginning of the pandemic Current CasesB","Laboratory confirmed, since the beginning of the pandemic Difference from"]].values[0]

plt.figure(figsize=(10, 6))
plt.bar(["TOTAL", "Hospitalized","Deceased", "Recovered","Current Cases","Difference"], values)
plt.xlabel("Columns")
plt.ylabel("Values")
plt.xticks(rotation = 'vertical')
plt.title(f"Values for Category {selected_category}")
plt.show()

# %% [markdown]
# # 25. Relationship between Districts and Incidence per 100 Reported

# %%
district_incidence_per_100 = data.groupby("District")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,+USAFD"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.bar(district_incidence_per_100["District"], district_incidence_per_100["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,+USAFD"],color='green')

plt.xlabel("District")
plt.ylabel("Sum of Reported Incidence per 100 cases")
plt.xticks(rotation = 'vertical') 

plt.title("Sum of Reported Incidence per 100 Cases by District")
plt.show()

# %% [markdown]
# # 26. Relationship between Laboratory confirmed Hospitalized and Reported Incidence per 100 (Different age boundary)

# %% [markdown]
# # 26.a. Relationship between Laboratory confirmed Hospitalized and Reported Incidence per 100, <20 Jahre

# %%
district_incidence_per_1001 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Hospitalized")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.bar(district_incidence_per_1001["Laboratory confirmed, since the beginning of the pandemic Hospitalized"], district_incidence_per_1001["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"],color='brown')

plt.xlabel("Hospitalized")
plt.ylabel("< 20 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of < 20 Jahre Cases by Hospitalized in different Districts")
plt.show()

# %% [markdown]
# # 26.b. Relationship between Laboratory confirmed Hospitalized and Reported Incidence per 100,20-59 JahreE

# %%
district_incidence_per_1002 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Hospitalized")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.bar(district_incidence_per_1002["Laboratory confirmed, since the beginning of the pandemic Hospitalized"], district_incidence_per_1002["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"],color='purple')

plt.xlabel("Hospitalized")
plt.ylabel(" 20-59 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of 20-59 Jahre Cases by Hospitalized in different Districts")
plt.show()

# %% [markdown]
# # 26.c. Relationship between Laboratory confirmed Hospitalized and Reported Incidence per 100, >=60 Jahre

# %%
district_incidence_per_1003 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Hospitalized")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.bar(district_incidence_per_1003["Laboratory confirmed, since the beginning of the pandemic Hospitalized"], district_incidence_per_1003["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"],color='green')

plt.xlabel("Hospitalized")
plt.ylabel(">=60 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of >=60 Jahre Cases by Hospitalized in different Districts")
plt.show()

# %% [markdown]
# # 27. Relationship between Laboratory confirmed Recovered and Reported Incidence per 100 (Different age boundary)

# %% [markdown]
# # 27.a. Relationship between Laboratory confirmed Recovered and Reported Incidence per 100, <20 Jahre

# %%
district_incidence_per_1004 = data.groupby("Laboratory confirmed, since the beginning of the pandemic RecoveredA")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"].sum().reset_index()

plt.figure(figsize=(6, 4))
plt.scatter(district_incidence_per_1004["Laboratory confirmed, since the beginning of the pandemic RecoveredA"], district_incidence_per_1004["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"],color='brown')

plt.xlabel("Recovered")
plt.ylabel("< 20 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of < 20 Jahre Cases by Recovered in different Districts")
plt.show()

# %% [markdown]
# # 27.b. Relationship between Laboratory confirmed Recovered and Reported Incidence per 100,20-59 JahreE

# %%
district_incidence_per_1005 = data.groupby("Laboratory confirmed, since the beginning of the pandemic RecoveredA")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"].sum().reset_index()

plt.figure(figsize=(8, 6))
plt.scatter(district_incidence_per_1005["Laboratory confirmed, since the beginning of the pandemic RecoveredA"], district_incidence_per_1005["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"],color='purple')

plt.xlabel("Recovered")
plt.ylabel(" 20-59 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of 20-59 Jahre Cases by Recovered in different Districts")
plt.show()

# %% [markdown]
# # 27.c. Relationship between Laboratory confirmed Recovered and Reported Incidence per 100, >=60 Jahre

# %%
district_incidence_per_1006 = data.groupby("Laboratory confirmed, since the beginning of the pandemic RecoveredA")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"].sum().reset_index()

plt.figure(figsize=(6, 4))
plt.scatter(district_incidence_per_1006["Laboratory confirmed, since the beginning of the pandemic RecoveredA"], district_incidence_per_1006["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"],color='green')

plt.xlabel("Recovered")
plt.ylabel(">=60 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of >=60 Jahre Cases by Recovered in different Districts")
plt.show()

# %% [markdown]
# # 28. Relationship between Laboratory confirmed Current cases and Reported Incidence per 100 (Different age boundary)

# %% [markdown]
# # 28.a. Relationship between Laboratory confirmed Current cases and Reported Incidence per 100, <20 Jahre

# %%
district_incidence_per_1007 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Current CasesB")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"].sum().reset_index()

plt.figure(figsize=(12, 6))
#plt.scatter(district_incidence_per_1007["Laboratory confirmed, since the beginning of the pandemic Current CasesB"], district_incidence_per_1007["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"],color='brown')
plt.bar(district_incidence_per_1007["Laboratory confirmed, since the beginning of the pandemic Current CasesB"], district_incidence_per_1007["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre"],color='brown')


plt.xlabel("Current Cases")
plt.ylabel("< 20 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of < 20 Jahre Cases by Current Cases in different Districts")
plt.show()

# %% [markdown]
# # 28.b. Relationship between Laboratory confirmed Current cases and Reported Incidence per 100,20-59 JahreE

# %%
district_incidence_per_1008 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Current CasesB")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"].sum().reset_index()

plt.figure(figsize=(8, 6))
plt.bar(district_incidence_per_1008["Laboratory confirmed, since the beginning of the pandemic Current CasesB"], district_incidence_per_1008["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE"],color='purple')

plt.xlabel("Current Cases")
plt.ylabel(" 20-59 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of 20-59 Jahre Cases by Current CasesB in different Districts")
plt.show()

# %% [markdown]
# # 28.c. Relationship between Laboratory confirmed Current cases and Reported Incidence per 100, >=60 Jahre

# %%
district_incidence_per_1009 = data.groupby("Laboratory confirmed, since the beginning of the pandemic Current CasesB")["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"].sum().reset_index()

plt.figure(figsize=(6, 4))
plt.scatter(district_incidence_per_1009["Laboratory confirmed, since the beginning of the pandemic Current CasesB"], district_incidence_per_1009["Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre"],color='cyan')

plt.xlabel("Current Cases")
plt.ylabel(">=60 Jahre")
plt.xticks(rotation = 'vertical') 

plt.title("Sum  of >=60 Jahre Cases by Current Cases in different Districts")
plt.show()

# %% [markdown]
# # 29.Reported COVID Cases of different ages

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,<20 Jahre'], label='<20 Jahre',color='blue')
plt.plot(data['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,20-59 JahreE'], label='20-59 Jahre',color='orange')
plt.plot(data['Reported, the last 7 days,Incidence per 100, Incidence per 100 ,>=60 Jahre'], label='>=60 Jahre',color='lime')
plt.xlabel('Time phase')
plt.ylabel('Number of Cases')
plt.legend()
plt.title('Reported COVID Cases of different ages')
plt.show()
