# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('lab_merged_data.xlsx', header=0)

# %%
data.head(2)
# Out:
#        District  \
# 0     Ahrweiler
# 1  Altenkirchen
#
#    Laboratory confirmed, since the beginning of the pandemic TOTAL  \
# 0                                             4577.0
# 1                                             4956.0
#
#   Laboratory confirmed, since the beginning of the pandemic Difference from  \
# 0                                                  4
# 1                                                  0
#
#   Laboratory confirmed, since the beginning of the pandemic Hospitalized  \
# 0                                                199
# 1                                                411
#
#   Laboratory confirmed, since the beginning of the pandemic Deceased  \
# 0                                                 52
# 1                                                101
#
#   Laboratory confirmed, since the beginning of the pandemic RecoveredA  \
# 0                                               4423
# 1                                               4833
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x = data['District'].astype(str)
y = data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].astype(str)

plt.scatter(x,y)  # Scatter plot
# or
#plt.plot(x,y)  # Line plot

# Add labels and title
plt.xlabel('X : Location')
plt.ylabel('Y : Hospitalized')
plt.title('Relationship: All Districts and Laboratory confirmed Hospitalized')

plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

#x = data['District'].astype(str)
v1 = 'Ahrweiler'
xx = data[data['District'] == v1]
final_v = xx['Laboratory confirmed, since the beginning of the pandemic Hospitalized']

plt.plot(final_v)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Hospitalized')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Hospitalized case')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x1 = data['District'].astype(str)
y1 = data['Laboratory confirmed, since the beginning of the pandemic Deceased'].astype(str)

plt.scatter(x1, y1)  # Scatter plot
# or
#plt.plot(x1, y1)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Deceased')
plt.title('Relationship: All Districts and Laboratory confirmed Deceased')




plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

v2 = 'Ahrweiler'
xx1 = data[data['District'] == v2]
final_v1 = xx1['Laboratory confirmed, since the beginning of the pandemic Deceased']

plt.plot(final_v1)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Deceased')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Deceased case')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired


x2 = data['District'].astype(str)
y2 = data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'].astype(str)

plt.scatter(x2, y2)  # Scatter plot
# or
#plt.plot(x2, y2)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Recovered')
plt.title('Relationship: All Districts and Laboratory confirmed Recovered')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

v3 = 'Ahrweiler'
xx2 = data[data['District'] == v3]
final_v2 = xx2['Laboratory confirmed, since the beginning of the pandemic RecoveredA']

plt.plot(final_v2)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Recovered')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Recovered case')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x3 = data['District'].astype(str)
y3 = data['Laboratory confirmed, since the beginning of the pandemic Current CasesB'].astype(str)

plt.scatter(x3, y3)  # Scatter plot
# or
#plt.plot(x3, y3)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Current Cases')
plt.title('Relationship: All Districts and Laboratory confirmed Current Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

v4 = 'Ahrweiler'
xx3 = data[data['District'] == v4]
final_v3 = xx3['Laboratory confirmed, since the beginning of the pandemic Current CasesB']

plt.plot(final_v3)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : Current Cases')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed Current Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x4 = data['District'].astype(str)
y4 = data['Laboratory confirmed, since the beginning of the pandemic TOTAL'].astype(str)

plt.scatter(x4, y4)  # Scatter plot
# or
#plt.plot(x4, y4)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : TOTAL Cases')
plt.title('Relationship: All Districts and Laboratory confirmed TOTAL Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

v5 = 'Ahrweiler'
xx4 = data[data['District'] == v5]
final_v4 = xx4['Laboratory confirmed, since the beginning of the pandemic TOTAL']

plt.plot(final_v4)  # Line plot

# Add labels and title
plt.xlabel('X : District')
plt.ylabel('Y : TOTAL cases')
plt.title('Relationship between District(''Ahrweiler'') and Laboratory confirmed TOTAL Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x5 = data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].astype(str)
y5 = data['Laboratory confirmed, since the beginning of the pandemic RecoveredA'].astype(str)

plt.scatter(x5, y5)  # Scatter plot
# or
#plt.plot(x5, y5)  # Line plot

# Add labels and title
plt.xlabel('X : Hospitalized')
plt.ylabel('Y : Recovered')
plt.title('Relationship: Laboratory confirmed Hospitalized and  Recovered Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
### Not necessary
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

x6 = data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].astype(str)
y6 = data['Laboratory confirmed, since the beginning of the pandemic Deceased'].astype(str)

plt.scatter(x6, y6)  # Scatter plot
# or
#plt.plot(x6, y6)  # Line plot

# Add labels and title
plt.xlabel('X : Hospitalized')
plt.ylabel('Y : Deceased')
plt.title('Relationship: Laboratory confirmed Hospitalized and  Deceased Cases')


plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt


# Specify the district you want to plot
district_name = 'Ahrweiler'

# Filter the data for the specified district
district_data = data[data['District'] == district_name]

# Calculate the count of each hospitalized cases
case_counts = district_data['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].value_counts()

# Get the labels and values for the pie chart
labels = case_counts.index
values = case_counts.values

# Create the pie chart
plt.pie(values, labels=labels)
plt.title('Hospitalized case Distribution for {}'.format(district_name))
plt.axis('equal')
plt.show()

# %%
import pandas as pd


# Search for a particular value in column 'A'
single_result = data[data['District'] == 'Ahrweiler']

# Print the result
#print(single_result)
single_result.head(3)
# Out:
#      District  \
# 0   Ahrweiler
# 36  Ahrweiler
# 72  Ahrweiler
#
#     Laboratory confirmed, since the beginning of the pandemic TOTAL  \
# 0                                              4577.0
# 36                                             4584.0
# 72                                             4584.0
#
#    Laboratory confirmed, since the beginning of the pandemic Difference from  \
# 0                                                   4
# 36                                                  7
# 72                                                  0
#
#    Laboratory confirmed, since the beginning of the pandemic Hospitalized  \
# 0                                                 199
# 36                                                199
# 72                                                199
#
#    Laboratory confirmed, since the beginning of the pandemic Deceased  \
# 0                                                  52
# 36                                                 52
# ...

# %%
# Filter the data for the specified district
district_data = single_result['District']

# Calculate the count of each hospitalized cases
case_counts = single_result['Laboratory confirmed, since the beginning of the pandemic Hospitalized'].value_counts()

# Get the labels and values for the pie chart
labels = case_counts.index
values = case_counts.values

# Create the pie chart
plt.pie(values, labels=labels)
#plt.title('Hospitalized case Distribution for {}'.format(district_name))
plt.axis('equal')
plt.show()

# %%
single_result.head(2)
# Out:
#      District  \
# 0   Ahrweiler
# 36  Ahrweiler
#
#     Laboratory confirmed, since the beginning of the pandemic TOTAL  \
# 0                                              4577.0
# 36                                             4584.0
#
#    Laboratory confirmed, since the beginning of the pandemic Difference from  \
# 0                                                   4
# 36                                                  7
#
#    Laboratory confirmed, since the beginning of the pandemic Hospitalized  \
# 0                                                 199
# 36                                                199
#
#    Laboratory confirmed, since the beginning of the pandemic Deceased  \
# 0                                                  52
# 36                                                 52
#
#    Laboratory confirmed, since the beginning of the pandemic RecoveredA  \
# 0                                                4423
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

# Assuming 'data' is your DataFrame and 'x_column' and 'y_column' are the columns you want to plot
x = single_result['Laboratory confirmed, since the beginning of the pandemic Hospitalized']
y = single_result['Laboratory confirmed, since the beginning of the pandemic RecoveredA']

plt.scatter(x, y)  # Scatter plot
# or
plt.plot(x, y)  # Line plot

# Add labels and title
plt.xlabel('X : Hospitalized')
plt.ylabel('Y : Recovered')
plt.title('Relationship between Hospitalized and Recovered')




plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))  # Set the figure size as desired

# Assuming 'data' is your DataFrame and 'x_column' and 'y_column' are the columns you want to plot
x = single_result['Laboratory confirmed, since the beginning of the pandemic Hospitalized']
y = single_result['Laboratory confirmed, since the beginning of the pandemic Deceased']

#plt.scatter(x, y)  # Scatter plot
# or
plt.plot(x, y)  # Line plot

# Add labels and title
plt.xlabel('X : Hospitalized')
plt.ylabel('Y : Deceased')
plt.title('Relationship between Hospitalized and Deceased')




plt.xticks(rotation = 'vertical')  


# Display the plot
plt.show()

# %%
# Create a histogram
plt.hist(single_result['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], bins=10)
# Out:
# (array([185.,  31.,  22.,  14.,  14.,  21.,  37.,  33.,  45.,  62.]),
#  array([ 4423. ,  8617.9, 12812.8, 17007.7, 21202.6, 25397.5, 29592.4,
#         33787.3, 37982.2, 42177.1, 46372. ]),
#  <BarContainer object of 10 artists>)

# %%
# Create a histogram
plt.hist(single_result['Laboratory confirmed, since the beginning of the pandemic Deceased'], bins=10)
# Out:
# (array([88., 28., 27., 77., 67., 32., 38., 28., 45., 34.]),
#  array([ 52. ,  60.7,  69.4,  78.1,  86.8,  95.5, 104.2, 112.9, 121.6,
#         130.3, 139. ]),
#  <BarContainer object of 10 artists>)

# %%
# Drop multiple columns
columns_to_drop = ['District']
single_result_n = single_result.drop(columns_to_drop, axis=1)

# %%
# worked for numpy bool error
np.bool = np.bool_

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exclude non-numerical columns from correlation calculation
#numerical_df = single_result_n.select_dtypes(include=[np.number])

# Calculate the correlation matrix
correlation_matrix = single_result_n.corr()

# Create a heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',cbar_kws={'shrink': 0.7},linecolor='white',fmt='.1f', linewidths=2.0)

# Set the plot title
plt.title('Correlation Matrix')

# Set the figure size
plt.figure(figsize=(10,8))

# Rotate the x-axis labels for better readability (optional)
#plt.xticks(rotation=45)


# Display the plot
plt.show()

# %%
#Correlations

# %%
# Calculate Pearson correlation
pearson_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='pearson').iloc[0, 1]

# Calculate Spearman correlation
spearman_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='spearman').iloc[0, 1]


# Calculate Kendalltau correlation
kendalltau_corr = single_result_n[['Laboratory confirmed, since the beginning of the pandemic Hospitalized', 'Laboratory confirmed, since the beginning of the pandemic RecoveredA']].corr(method='kendall').iloc[0, 1]


print('Pearson correlation:', pearson_corr)
print('Spearman correlation:', spearman_corr)
print('kendalltau correlation:', kendalltau_corr)
# Out:
# Pearson correlation: 0.974041348911836
# Spearman correlation: 0.9999000675172401
# kendalltau correlation: 0.9964717662657261

# %%
#pearson
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr


# Calculate the Spearman correlation coefficient and p-value
correlation_coefficient, _ = pearsonr(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

# Calculate the correlation matrix
correlation_matrix = single_result_n.corr()

# Create a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(data=single_result_n, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Hospitalized')
plt.title('Scatter Plot (Pearson correlation: {:.2f})'.format(correlation_coefficient))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')

# Create a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Pearson Correlation Heatmap')


# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-3d629cf3e4e1> in <module>
#       8
#       9 # Calculate the Spearman correlation coefficient and p-value
# ---> 10 correlation_coefficient, _ = pearsonr(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])
#      11
#      12 # Calculate the correlation matrix
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_py.py in pearsonr(x, y, alternative)
#    4450     # [-5e210, 5e210, 3e200, -3e200]
#    4451     normxm = linalg.norm(xm)
# -> 4452     normym = linalg.norm(ym)
#    4453
#    4454     threshold = 1e-13
#
# ~\anaconda3\lib\site-packages\scipy\linalg\_misc.py in norm(a, ord, axis, keepdims, check_finite)
# ...

# %%
#Spearman correlation
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr


# Calculate the Spearman correlation coefficient and p-value
correlation_coefficient, _ = spearmanr(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

# Create a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(data=single_result, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Spearman correlation: {:.2f})'.format(correlation_coefficient))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')

# Show the scatter plot
plt.show()

# Create a heatmap of the Spearman correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(single_result_n.corr(method='spearman'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Spearman Correlation Heatmap')

# Show the heatmap
plt.show()

# %%
## Kendalltau correlation
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kendalltau

#Calculate the Kendall's tau correlation coefficient and p-value
correlation_coefficient1, _ = kendalltau(single_result_n['Laboratory confirmed, since the beginning of the pandemic RecoveredA'], single_result_n['Laboratory confirmed, since the beginning of the pandemic Hospitalized'])

# Create a scatter plot
plt.figure(figsize=(6, 4))
sns.scatterplot(data=single_result_n, x='Laboratory confirmed, since the beginning of the pandemic RecoveredA', y='Laboratory confirmed, since the beginning of the pandemic Hospitalized')
plt.title('Scatter Plot (Kendall correlation: {:.2f})'.format(correlation_coefficient1))
plt.xlabel('Recovered')
plt.ylabel('Hospitalized')

# Show the scatter plot
plt.show()

# Create a heatmap of the Kendall's tau correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(single_result_n.corr(method='kendall'), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Kendall Correlation Heatmap')

# Show the heatmap
plt.show()
